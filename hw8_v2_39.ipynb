# %% [markdown]
# # **Homework 8 - Anomaly Detection**
#
# If there are any questions, please contact mlta-2022spring-ta@googlegroups.com
#
# Slide:    [Link]()　Kaggle: [Link](https://www.kaggle.com/c/ml2022spring-hw8)

# %% [markdown]
# # Set up the environment

# %% [markdown]
# ## Package installation

# %%
# # Training progress bar
# !pip install -q qqdm

# %% [markdown]
# ## Downloading data

# %%
# !wget https://github.com/MachineLearningHW/HW8_Dataset/releases/download/v1.0.0/data.zip

# %%
# !unzip data.zip

# %% [markdown]
# # Import packages

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "7"

# %%
import random
import numpy as np
import torch
from torch import nn
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset
import torchvision.transforms as transforms
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision.models as models
from torch.optim import Adam, AdamW
from qqdm import qqdm, format_str
import pandas as pd

# %% [markdown]
# # Loading data

# %%
train = np.load('data/trainingset.npy', allow_pickle=True)
test = np.load('data/testingset.npy', allow_pickle=True)

print(train.shape)
print(test.shape)
# Out:
# (100000, 64, 64, 3)
# (19636, 64, 64, 3)

# %% [markdown]
# ## Random seed
# Set the random seed to a certain value for reproducibility.

# %%
def same_seeds(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

same_seeds(16)

# %% [markdown]
# # Autoencoder

# %% [markdown]
# # Models & loss

# %%
class fcn_autoencoder(nn.Module):
    def __init__(self):
        super(fcn_autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            # nn.Linear(64 * 64 * 3, 128),
            # nn.ReLU(),
            # nn.Linear(128, 64),
            # nn.ReLU(), 
            # nn.Linear(64, 12), 
            # nn.ReLU(), 
            # nn.Linear(12, 3)
            
            nn.Linear(64 * 64 * 3, 64),
            nn.ReLU(), 
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 3)
        )
        
        self.decoder = nn.Sequential(
            # nn.Linear(3, 12),
            # nn.ReLU(), 
            # nn.Linear(12, 64),
            # nn.ReLU(),
            # nn.Linear(64, 128),
            # nn.ReLU(), 
            # nn.Linear(128, 64 * 64 * 3), 
            # nn.Tanh()
            
            nn.Linear(3, 16),
            nn.ReLU(), 
            nn.Linear(16, 32),
            nn.ReLU(),
            nn.Linear(32, 64),
            nn.ReLU(),
            nn.Linear(64, 64 * 64 * 3), 
            nn.Tanh()
        )

    def forward(self, x):
        x = self.encoder(x)
        x[:, 2] = 0
        x = self.decoder(x)
        return x


class conv_autoencoder(nn.Module):
    def __init__(self):
        super(conv_autoencoder, self).__init__()
			# self.encoder = nn.Sequential(
			# nn.Conv2d(3, 12, 4, stride=2, padding=1),         
			# nn.ReLU(),
			# nn.Conv2d(12, 24, 4, stride=2, padding=1),        
			# nn.ReLU(),
			# nn.Conv2d(24, 48, 4, stride=2, padding=1),         
			# nn.ReLU(),
			# )
			# self.decoder = nn.Sequential(
			# nn.ConvTranspose2d(48, 24, 4, stride=2, padding=1),
			# nn.ReLU(),
			# nn.ConvTranspose2d(24, 12, 4, stride=2, padding=1), 
			# nn.ReLU(),
			# nn.ConvTranspose2d(12, 3, 4, stride=2, padding=1),
			# nn.Tanh(),
			# )
        
			# self.encoder = nn.Sequential(
			# nn.Conv2d(3, 16, 4, stride=2, padding=1),         
			# nn.ReLU(),
			# nn.Conv2d(16, 32, 4, stride=2, padding=1),         
			# nn.ReLU(),
			# nn.Conv2d(32, 64, 4, stride=2, padding=1),        
			# nn.ReLU(),
			# )
			# self.decoder = nn.Sequential(
			# nn.ConvTranspose2d(64, 32, 4, stride=2, padding=1), 
			# nn.ReLU(),
			# nn.ConvTranspose2d(32, 16, 4, stride=2, padding=1), 
			# nn.ReLU(),
			# nn.ConvTranspose2d(16, 3, 4, stride=2, padding=1),
			# nn.Tanh(),
			# )
        
        
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 128, 4, stride=2, padding=1), 
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128, 256, 4, stride=2, padding=1), 
            nn.BatchNorm2d(256),
            nn.ReLU(),
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(256, 128, 4, stride=2, padding=1), 
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 3, 4, stride=2, padding=1),
            nn.Tanh(),
        )
            

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
    
    
class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()
        # self.encoder = nn.Sequential(
        #     nn.Conv2d(3, 12, 4, stride=2, padding=1),            
        #     nn.ReLU(),
        #     nn.Conv2d(12, 24, 4, stride=2, padding=1),    
        #     nn.ReLU(),
        # )
        # self.enc_out_1 = nn.Sequential(
        #     nn.Conv2d(24, 48, 4, stride=2, padding=1),  
        #     nn.ReLU(),
        # )
        # self.enc_out_2 = nn.Sequential(
        #     nn.Conv2d(24, 48, 4, stride=2, padding=1),
        #     nn.ReLU(),
        # )
        # self.decoder = nn.Sequential(
        # nn.ConvTranspose2d(48, 24, 4, stride=2, padding=1), 
        #     nn.ReLU(),
        # nn.ConvTranspose2d(24, 12, 4, stride=2, padding=1), 
        #     nn.ReLU(),
        #     nn.ConvTranspose2d(12, 3, 4, stride=2, padding=1), 
        #     nn.Tanh(),
        # )
        
        
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, 4, stride=2, padding=1),            
            nn.ReLU(),
            nn.Conv2d(32, 64, 4, stride=2, padding=1),    
            nn.ReLU(),
            nn.Conv2d(64, 128, 4, stride=2, padding=1),    
            nn.ReLU(),
        )
        self.enc_out_1 = nn.Sequential(
            nn.Conv2d(128, 256, 4, stride=2, padding=1),  
            nn.ReLU(),
        )
        self.enc_out_2 = nn.Sequential(
            nn.Conv2d(128, 256, 4, stride=2, padding=1),
            nn.ReLU(),
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(256, 128, 4, stride=2, padding=1), 
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, 4, stride=2, padding=1), 
            nn.ReLU(),
            nn.ConvTranspose2d(64, 32, 4, stride=2, padding=1), 
            nn.ReLU(),
            nn.ConvTranspose2d(32, 3, 4, stride=2, padding=1), 
            nn.Tanh(),
        )

    def encode(self, x):
        h1 = self.encoder(x)
        return self.enc_out_1(h1), self.enc_out_2(h1)

    def reparametrize(self, mu, logvar):
        std = logvar.mul(0.5).exp_()
        if torch.cuda.is_available():
            eps = torch.cuda.FloatTensor(std.size()).normal_()
        else:
            eps = torch.FloatTensor(std.size()).normal_()
        eps = Variable(eps)
        return eps.mul(std).add_(mu)

    def decode(self, z):
        return self.decoder(z)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparametrize(mu, logvar)
        return self.decode(z), mu, logvar


def loss_vae(recon_x, x, mu, logvar, criterion):
    """
    recon_x: generating images
    x: origin images
    mu: latent mean
    logvar: latent log variance
    """
    mse = criterion(recon_x, x)
    KLD_element = mu.pow(2).add_(logvar.exp()).mul_(-1).add_(1).add_(logvar)
    KLD = torch.sum(KLD_element).mul_(-0.5)
    return mse + KLD

# %%
class multi_fcn(nn.Module):
    def __init__(self):
        super(multi_fcn, self).__init__()
        
        self.encoder1 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 64),
            nn.ReLU(), 
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 3)
        )
        
        self.encoder2 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 1024),
            nn.ReLU(), 
            nn.Linear(1024, 256),
            nn.ReLU(),
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Linear(64, 3)
        )
        
        self.encoder3 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 512),
            nn.ReLU(), 
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Linear(128, 3)
        )
        
        self.encoder4 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 1024),
            nn.ReLU(),
            nn.Linear(1024, 64),
            nn.ReLU(),
            nn.Linear(64, 3)
        )
        
        self.encoder5 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 256),
            nn.ReLU(), 
            nn.Linear(256, 192),
            nn.ReLU(),
            nn.Linear(192, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 3)
        )
                
        self.decoder = nn.Sequential(
            nn.Linear(15, 64),
            nn.ReLU(), 
            nn.Linear(64, 1024),
            nn.ReLU(),
            nn.Linear(1024, 64 * 64 * 3), 
            nn.Tanh()
        )

    def forward(self, x):
        x1 = self.encoder1(x)
        x2 = self.encoder2(x)
        x3 = self.encoder3(x)
        x4 = self.encoder4(x)
        x5 = self.encoder5(x)
        x = torch.cat([x1, x2, x3, x4, x5], 1)
        
        x = x + torch.randn(x.shape).cuda() * 0.2
        
        x = self.decoder(x)
        return x

# %% [markdown]
# # Dataset module
#
# Module for obtaining and processing data. The transform function here normalizes image's pixels from [0, 255] to [-1.0, 1.0].

# %%
class CustomTensorDataset(TensorDataset):
    """TensorDataset with support of transforms.
    """
    def __init__(self, tensors):
        self.tensors = tensors
        if tensors.shape[-1] == 3:
            self.tensors = tensors.permute(0, 3, 1, 2)
        
        self.transform = transforms.Compose([
          transforms.Lambda(lambda x: x.to(torch.float32)),
          transforms.Lambda(lambda x: 2. * x/255. - 1.),
        ])
        
    def __getitem__(self, index):
        x = self.tensors[index]
        
        if self.transform:
            # mapping images to [-1.0, 1.0]
            x = self.transform(x)

        return x

    def __len__(self):
        return len(self.tensors)

# %% [markdown]
# # Training

# %% [markdown]
# ## Configuration

# %%
# Training hyperparameters
num_epochs = 500
batch_size = 10000
learning_rate = 1e-3

# Build training dataloader
x = torch.from_numpy(train)
train_dataset = CustomTensorDataset(x)

train_sampler = RandomSampler(train_dataset)
train_dataloader = DataLoader(train_dataset, sampler=train_sampler, batch_size=batch_size)

# Model
model_type = 'multi_fcn'   # selecting a model type from {'cnn', 'fcn', 'vae', 'resnet'}
model_classes = {'fcn': fcn_autoencoder(), 'cnn': conv_autoencoder(), 'vae': VAE(), 'multi_fcn': multi_fcn()}
model = model_classes[model_type].cuda()

# Loss and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# print(model)

# %% [markdown]
# ## Training loop

# %%
best_loss = np.inf
model.train()

qqdm_train = qqdm(range(num_epochs), desc=format_str('bold', 'Description'))
for epoch in qqdm_train:
    
    tot_loss = list()
    for data in train_dataloader:

        # ===================loading=====================
        img = data.float().cuda()
        if model_type in ['fcn']:
            img = img.view(img.shape[0], -1)
        if model_type in ['multi_fcn']:
            img = img.view(img.shape[0], -1)
            
        # noise = torch.randn_like(img) * 0.2
        # img = img + noise    

        # ===================forward=====================
        output = model(img)
        if model_type in ['vae']:
            loss = loss_vae(output[0], img, output[1], output[2], criterion)
        else:
            loss = criterion(output, img)

        tot_loss.append(loss.item())
        # ===================backward====================
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    # ===================save_best====================
    mean_loss = np.mean(tot_loss)
    if mean_loss < best_loss:
        best_loss = mean_loss
        torch.save(model, 'best_model_{}.pt'.format(model_type))
    # ===================log========================
    qqdm_train.set_infos({
        'epoch': f'{epoch + 1:.0f}/{num_epochs:.0f}',
        'loss': f'{mean_loss:.4f}',
    })
    # ===================save_last========================
    torch.save(model, 'last_model_{}.pt'.format(model_type))
# Out:
#  Iters    Elapsed Time      Speed
#  0/500          -             -
# Description   0.0% |                                                                                                   | Iters    Elapsed Time      Speed    epoch   loss
#  1/500  00:00:15<02:05:39  0.07it/s  1/500  0.2831
# Description   0.2% |                                                                                                   | Iters    Elapsed Time      Speed    epoch   loss
#  2/500  00:00:30<02:04:31  0.07it/s  2/500  0.1995
# Description   0.4% |                                                                                                   | Iters    Elapsed Time      Speed    epoch   loss
#  3/500  00:00:44<02:03:06  0.07it/s  3/500  0.1813
# Description   0.6% |                                                                                                   | Iters    Elapsed Time      Speed    epoch   loss
#  4/500  00:00:59<02:02:01  0.07it/s  4/500  0.1581
# Description   0.8% |                                                                                                   | Iters    Elapsed Time      Speed    epoch   loss
#  5/500  00:01:13<02:01:46  0.07it/s  5/500  0.1369
# Description   1.0% |                                                                                                   | Iters    Elapsed Time      Speed    epoch   loss
#  6/500  00:01:28<02:01:19  0.07it/s  6/500  0.1229
# Description   1.2% |█                                                                                                  | Iters    Elapsed Time      Speed    epoch   loss
#  7/500  00:01:42<02:00:42  0.07it/s  7/500  0.1157
# Description   1.4% |█                                                                                                  | Iters    Elapsed Time      Speed    epoch   loss
#  8/500  00:01:57<01:59:55  0.07it/s  8/500  0.1113
# Description   1.6% |█                                                                                                  | Iters    Elapsed Time      Speed    epoch   loss
#  9/500  00:02:11<01:59:09  0.07it/s  9/500  0.1073
# Description   1.8% |█                                                                                                  | Iters     Elapsed Time      Speed    epoch    loss
#  10/500  00:02:25<01:59:09  0.07it/s  10/500  0.1039
# Description   2.0% |█                                                                                                  | Iters     Elapsed Time      Speed    epoch    loss
#  11/500  00:02:41<01:59:18  0.07it/s  11/500  0.1007
# Description   2.2% |██                                                                                                 | Iters     Elapsed Time      Speed    epoch    loss
#  12/500  00:02:55<01:59:02  0.07it/s  12/500  0.0982
# Description   2.4% |██                                                                                                 | Iters     Elapsed Time      Speed    epoch    loss
#  13/500  00:03:09<01:58:09  0.07it/s  13/500  0.0951
# Description   2.6% |██                                                                                                 | Iters     Elapsed Time      Speed    epoch    loss
#  14/500  00:03:22<01:57:25  0.07it/s  14/500  0.0927
# Description   2.8% |██                                                                                                 | Iters     Elapsed Time      Speed    epoch    loss
#  15/500  00:03:37<01:57:20  0.07it/s  15/500  0.0907
# Description   3.0% |██                                                                                                 | Iters     Elapsed Time      Speed    epoch    loss
#  16/500  00:03:52<01:57:08  0.07it/s  16/500  0.0887
# Description   3.2% |███                                                                                                | Iters     Elapsed Time      Speed    epoch    loss
#  17/500  00:04:05<01:56:20  0.07it/s  17/500  0.0882
# Description   3.4% |███                                                                                                | Iters     Elapsed Time      Speed    epoch    loss
#  18/500  00:04:18<01:55:17  0.07it/s  18/500  0.0864
# Description   3.6% |███                                                                                                | Iters     Elapsed Time      Speed    epoch    loss
#  19/500  00:04:30<01:54:09  0.07it/s  19/500  0.0852
# Description   3.8% |███                                                                                                | Iters     Elapsed Time      Speed    epoch    loss
#  20/500  00:04:42<01:53:01  0.07it/s  20/500  0.0844
# Description   4.0% |███                                                                                                | Iters     Elapsed Time      Speed    epoch    loss
#  21/500  00:04:54<01:51:55  0.07it/s  21/500  0.0840
# Description   4.2% |████                                                                                               | Iters     Elapsed Time      Speed    epoch    loss
#  22/500  00:05:06<01:50:55  0.07it/s  22/500  0.0826
# Description   4.4% |████                                                                                               | Iters     Elapsed Time      Speed    epoch    loss
#  23/500  00:05:18<01:50:07  0.07it/s  23/500  0.0822
# Description   4.6% |████                                                                                               | Iters     Elapsed Time      Speed    epoch    loss
#  24/500  00:05:30<01:49:19  0.07it/s  24/500  0.0813
# Description   4.8% |████                                                                                               | Iters     Elapsed Time      Speed    epoch    loss
#  25/500  00:05:42<01:48:28  0.07it/s  25/500  0.0806
# Description   5.0% |████                                                                                               | Iters     Elapsed Time      Speed    epoch    loss
#  26/500  00:05:54<01:47:47  0.07it/s  26/500  0.0801
# Description   5.2% |█████                                                                                              | Iters     Elapsed Time      Speed    epoch    loss
#  27/500  00:06:06<01:47:00  0.07it/s  27/500  0.0802
# Description   5.4% |█████                                                                                              | Iters     Elapsed Time      Speed    epoch    loss
#  28/500  00:06:18<01:46:24  0.07it/s  28/500  0.0794
# Description   5.6% |█████                                                                                              | Iters     Elapsed Time      Speed    epoch    loss
#  29/500  00:06:31<01:45:53  0.07it/s  29/500  0.0792
# Description   5.8% |█████                                                                                              | Iters     Elapsed Time      Speed    epoch    loss
#  30/500  00:06:43<01:45:19  0.07it/s  30/500  0.0788
# Description   6.0% |█████                                                                                              | Iters     Elapsed Time      Speed    epoch    loss
#  31/500  00:06:55<01:44:46  0.07it/s  31/500  0.0782
# Description   6.2% |██████                                                                                             | Iters     Elapsed Time      Speed    epoch    loss
#  32/500  00:07:07<01:44:09  0.07it/s  32/500  0.0784
# Description   6.4% |██████                                                                                             | Iters     Elapsed Time      Speed    epoch    loss
#  33/500  00:07:19<01:43:34  0.08it/s  33/500  0.0784
# Description   6.6% |██████                                                                                             | Iters     Elapsed Time      Speed    epoch    loss
#  34/500  00:07:31<01:43:08  0.08it/s  34/500  0.0776
# Description   6.8% |██████                                                                                             | Iters     Elapsed Time      Speed    epoch    loss
#  35/500  00:07:44<01:42:45  0.08it/s  35/500  0.0773
# Description   7.0% |██████                                                                                             | Iters     Elapsed Time      Speed    epoch    loss
#  36/500  00:07:56<01:42:22  0.08it/s  36/500  0.0772
# Description   7.2% |███████                                                                                            | Iters     Elapsed Time      Speed    epoch    loss
#  37/500  00:08:08<01:41:51  0.08it/s  37/500  0.0773
# Description   7.4% |███████                                                                                            | Iters     Elapsed Time      Speed    epoch    loss
#  38/500  00:08:20<01:41:25  0.08it/s  38/500  0.0767
# Description   7.6% |███████                                                                                            | Iters     Elapsed Time      Speed    epoch    loss
#  39/500  00:08:32<01:40:52  0.08it/s  39/500  0.0773
# Description   7.8% |███████                                                                                            | Iters     Elapsed Time      Speed    epoch    loss
#  40/500  00:08:43<01:40:20  0.08it/s  40/500  0.0768
# Description   8.0% |███████                                                                                            | Iters     Elapsed Time      Speed    epoch    loss
#  41/500  00:08:55<01:39:59  0.08it/s  41/500  0.0762
# Description   8.2% |████████                                                                                           | Iters     Elapsed Time      Speed    epoch    loss
#  42/500  00:09:08<01:39:38  0.08it/s  42/500  0.0759
# Description   8.4% |████████                                                                                           | Iters     Elapsed Time      Speed    epoch    loss
#  43/500  00:09:20<01:39:15  0.08it/s  43/500  0.0758
# Description   8.6% |████████                                                                                           | Iters     Elapsed Time      Speed    epoch    loss
#  44/500  00:09:32<01:38:48  0.08it/s  44/500  0.0762
# Description   8.8% |████████                                                                                           | Iters     Elapsed Time      Speed    epoch    loss
#  45/500  00:09:44<01:38:26  0.08it/s  45/500  0.0758
# Description   9.0% |████████                                                                                           | Iters     Elapsed Time      Speed    epoch    loss
#  46/500  00:09:56<01:38:05  0.08it/s  46/500  0.0754
# Description   9.2% |█████████                                                                                          | Iters     Elapsed Time      Speed    epoch    loss
#  47/500  00:10:08<01:37:45  0.08it/s  47/500  0.0752
# Description   9.4% |█████████                                                                                          | Iters     Elapsed Time      Speed    epoch    loss
#  48/500  00:10:20<01:37:25  0.08it/s  48/500  0.0752
# Description   9.6% |█████████                                                                                          | Iters     Elapsed Time      Speed    epoch    loss
#  49/500  00:10:32<01:37:01  0.08it/s  49/500  0.0771
# Description   9.8% |█████████                                                                                          | Iters     Elapsed Time      Speed    epoch    loss
#  50/500  00:10:44<01:36:40  0.08it/s  50/500  0.0754
# Description  10.0% |█████████                                                                                          | Iters     Elapsed Time      Speed    epoch    loss
#  51/500  00:10:56<01:36:22  0.08it/s  51/500  0.0749
# Description  10.2% |██████████                                                                                         | Iters     Elapsed Time      Speed    epoch    loss
#  52/500  00:11:09<01:36:06  0.08it/s  52/500  0.0746
# Description  10.4% |██████████                                                                                         | Iters     Elapsed Time      Speed    epoch    loss
#  53/500  00:11:21<01:35:50  0.08it/s  53/500  0.0745
# Description  10.6% |██████████                                                                                         | Iters     Elapsed Time      Speed    epoch    loss
#  54/500  00:11:34<01:35:33  0.08it/s  54/500  0.0751
# Description  10.8% |██████████                                                                                         | Iters     Elapsed Time      Speed    epoch    loss
#  55/500  00:11:46<01:35:15  0.08it/s  55/500  0.0751
# Description  11.0% |██████████                                                                                         | Iters     Elapsed Time      Speed    epoch    loss
#  56/500  00:11:59<01:35:03  0.08it/s  56/500  0.0744
# Description  11.2% |███████████                                                                                        | Iters     Elapsed Time      Speed    epoch    loss
#  57/500  00:12:12<01:34:51  0.08it/s  57/500  0.0741
# Description  11.4% |███████████                                                                                        | Iters     Elapsed Time      Speed    epoch    loss
#  58/500  00:12:25<01:34:40  0.08it/s  58/500  0.0741
# Description  11.6% |███████████                                                                                        | Iters     Elapsed Time      Speed    epoch    loss
#  59/500  00:12:37<01:34:24  0.08it/s  59/500  0.0746
# Description  11.8% |███████████                                                                                        | Iters     Elapsed Time      Speed    epoch    loss
#  60/500  00:12:50<01:34:12  0.08it/s  60/500  0.0739
# Description  12.0% |███████████                                                                                        | Iters     Elapsed Time      Speed    epoch    loss
#  61/500  00:13:03<01:33:57  0.08it/s  61/500  0.0738
# Description  12.2% |████████████                                                                                       | Iters     Elapsed Time      Speed    epoch    loss
#  62/500  00:13:15<01:33:42  0.08it/s  62/500  0.0737
# Description  12.4% |████████████                                                                                       | Iters     Elapsed Time      Speed    epoch    loss
#  63/500  00:13:28<01:33:24  0.08it/s  63/500  0.0739
# Description  12.6% |████████████                                                                                       | Iters     Elapsed Time      Speed    epoch    loss
#  64/500  00:13:39<01:33:05  0.08it/s  64/500  0.0741
# Description  12.8% |████████████                                                                                       | Iters     Elapsed Time      Speed    epoch    loss
#  65/500  00:13:52<01:32:52  0.08it/s  65/500  0.0735
# Description  13.0% |████████████                                                                                       | Iters     Elapsed Time      Speed    epoch    loss
#  66/500  00:14:05<01:32:41  0.08it/s  66/500  0.0733
# Description  13.2% |█████████████                                                                                      | Iters     Elapsed Time      Speed    epoch    loss
#  67/500  00:14:18<01:32:28  0.08it/s  67/500  0.0737
# Description  13.4% |█████████████                                                                                      | Iters     Elapsed Time      Speed    epoch    loss
#  68/500  00:14:31<01:32:15  0.08it/s  68/500  0.0743
# Description  13.6% |█████████████                                                                                      | Iters     Elapsed Time      Speed    epoch    loss
#  69/500  00:14:43<01:32:00  0.08it/s  69/500  0.0734
# Description  13.8% |█████████████                                                                                      | Iters     Elapsed Time      Speed    epoch    loss
#  70/500  00:14:56<01:31:47  0.08it/s  70/500  0.0731
# Description  14.0% |█████████████                                                                                      | Iters     Elapsed Time      Speed    epoch    loss
#  71/500  00:15:09<01:31:32  0.08it/s  71/500  0.0729
# Description  14.2% |██████████████                                                                                     | Iters     Elapsed Time      Speed    epoch    loss
#  72/500  00:15:21<01:31:19  0.08it/s  72/500  0.0729
# Description  14.4% |██████████████                                                                                     | Iters     Elapsed Time      Speed    epoch    loss
#  73/500  00:15:34<01:31:05  0.08it/s  73/500  0.0734
# Description  14.6% |██████████████                                                                                     | Iters     Elapsed Time      Speed    epoch    loss
#  74/500  00:15:46<01:30:51  0.08it/s  74/500  0.0730
# Description  14.8% |██████████████                                                                                     | Iters     Elapsed Time      Speed    epoch    loss
#  75/500  00:15:59<01:30:37  0.08it/s  75/500  0.0729
# Description  15.0% |██████████████                                                                                     | Iters     Elapsed Time      Speed    epoch    loss
#  76/500  00:16:12<01:30:25  0.08it/s  76/500  0.0728
# Description  15.2% |███████████████                                                                                    | Iters     Elapsed Time      Speed    epoch    loss
#  77/500  00:16:25<01:30:14  0.08it/s  77/500  0.0727
# Description  15.4% |███████████████                                                                                    | Iters     Elapsed Time      Speed    epoch    loss
#  78/500  00:16:37<01:29:59  0.08it/s  78/500  0.0727
# Description  15.6% |███████████████                                                                                    | Iters     Elapsed Time      Speed    epoch    loss
#  79/500  00:16:49<01:29:40  0.08it/s  79/500  0.0730
# Description  15.8% |███████████████                                                                                    | Iters     Elapsed Time      Speed    epoch    loss
#  80/500  00:17:02<01:29:26  0.08it/s  80/500  0.0725
# Description  16.0% |███████████████                                                                                    | Iters     Elapsed Time      Speed    epoch    loss
#  81/500  00:17:14<01:29:13  0.08it/s  81/500  0.0724
# Description  16.2% |████████████████                                                                                   | Iters     Elapsed Time      Speed    epoch    loss
#  82/500  00:17:27<01:28:58  0.08it/s  82/500  0.0726
# Description  16.4% |████████████████                                                                                   | Iters     Elapsed Time      Speed    epoch    loss
#  83/500  00:17:39<01:28:43  0.08it/s  83/500  0.0724
# Description  16.6% |████████████████                                                                                   | Iters     Elapsed Time      Speed    epoch    loss
#  84/500  00:17:52<01:28:31  0.08it/s  84/500  0.0723
# Description  16.8% |████████████████                                                                                   | Iters     Elapsed Time      Speed    epoch    loss
#  85/500  00:18:04<01:28:16  0.08it/s  85/500  0.0727
# Description  17.0% |████████████████                                                                                   | Iters     Elapsed Time      Speed    epoch    loss
#  86/500  00:18:17<01:28:03  0.08it/s  86/500  0.0723
# Description  17.2% |█████████████████                                                                                  | Iters     Elapsed Time      Speed    epoch    loss
#  87/500  00:18:30<01:27:51  0.08it/s  87/500  0.0720
# Description  17.4% |█████████████████                                                                                  | Iters     Elapsed Time      Speed    epoch    loss
#  88/500  00:18:43<01:27:39  0.08it/s  88/500  0.0719
# Description  17.6% |█████████████████                                                                                  | Iters     Elapsed Time      Speed    epoch    loss
#  89/500  00:18:55<01:27:25  0.08it/s  89/500  0.0730
# Description  17.8% |█████████████████                                                                                  | Iters     Elapsed Time      Speed    epoch    loss
#  90/500  00:19:08<01:27:11  0.08it/s  90/500  0.0723
# Description  18.0% |█████████████████                                                                                  | Iters     Elapsed Time      Speed    epoch    loss
#  91/500  00:19:20<01:26:57  0.08it/s  91/500  0.0719
# Description  18.2% |██████████████████                                                                                 | Iters     Elapsed Time      Speed    epoch    loss
#  92/500  00:19:34<01:26:46  0.08it/s  92/500  0.0718
# Description  18.4% |██████████████████                                                                                 | Iters     Elapsed Time      Speed    epoch    loss
#  93/500  00:19:46<01:26:32  0.08it/s  93/500  0.0720
# Description  18.6% |██████████████████                                                                                 | Iters     Elapsed Time      Speed    epoch    loss
#  94/500  00:19:59<01:26:20  0.08it/s  94/500  0.0723
# Description  18.8% |██████████████████                                                                                 | Iters     Elapsed Time      Speed    epoch    loss
#  95/500  00:20:11<01:26:06  0.08it/s  95/500  0.0718
# Description  19.0% |██████████████████                                                                                 | Iters     Elapsed Time      Speed    epoch    loss
#  96/500  00:20:24<01:25:55  0.08it/s  96/500  0.0716
# Description  19.2% |███████████████████                                                                                | Iters     Elapsed Time      Speed    epoch    loss
#  97/500  00:20:37<01:25:43  0.08it/s  97/500  0.0716
# Description  19.4% |███████████████████                                                                                | Iters     Elapsed Time      Speed    epoch    loss
#  98/500  00:20:50<01:25:29  0.08it/s  98/500  0.0717
# Description  19.6% |███████████████████                                                                                | Iters     Elapsed Time      Speed    epoch    loss
#  99/500  00:21:02<01:25:13  0.08it/s  99/500  0.0717
# Description  19.8% |███████████████████                                                                                |  Iters     Elapsed Time      Speed     epoch    loss
#  100/500  00:21:14<01:24:57  0.08it/s  100/500  0.0716
# Description  20.0% |███████████████████                                                                                |  Iters     Elapsed Time      Speed     epoch    loss
#  101/500  00:21:26<01:24:43  0.08it/s  101/500  0.0716
# Description  20.2% |███████████████████                                                                                |  Iters     Elapsed Time      Speed     epoch    loss
#  102/500  00:21:41<01:24:37  0.08it/s  102/500  0.0717
# Description  20.4% |████████████████████                                                                               |  Iters     Elapsed Time      Speed     epoch    loss
#  103/500  00:21:55<01:24:29  0.08it/s  103/500  0.0713
# Description  20.6% |████████████████████                                                                               |  Iters     Elapsed Time      Speed     epoch    loss
#  104/500  00:22:07<01:24:16  0.08it/s  104/500  0.0713
# Description  20.8% |████████████████████                                                                               |  Iters     Elapsed Time      Speed     epoch    loss
#  105/500  00:22:19<01:24:00  0.08it/s  105/500  0.0712
# Description  21.0% |████████████████████                                                                               |  Iters     Elapsed Time      Speed     epoch    loss
#  106/500  00:22:31<01:23:44  0.08it/s  106/500  0.0714
# Description  21.2% |████████████████████                                                                               |  Iters     Elapsed Time      Speed     epoch    loss
#  107/500  00:22:43<01:23:27  0.08it/s  107/500  0.0714
# Description  21.4% |█████████████████████                                                                              |  Iters     Elapsed Time      Speed     epoch    loss
#  108/500  00:22:55<01:23:13  0.08it/s  108/500  0.0711
# Description  21.6% |█████████████████████                                                                              |  Iters     Elapsed Time      Speed     epoch    loss
#  109/500  00:23:07<01:22:57  0.08it/s  109/500  0.0712
# Description  21.8% |█████████████████████                                                                              |  Iters     Elapsed Time      Speed     epoch    loss
#  110/500  00:23:19<01:22:40  0.08it/s  110/500  0.0712
# Description  22.0% |█████████████████████                                                                              |  Iters     Elapsed Time      Speed     epoch    loss
#  111/500  00:23:30<01:22:24  0.08it/s  111/500  0.0712
# Description  22.2% |█████████████████████                                                                              |  Iters     Elapsed Time      Speed     epoch    loss
#  112/500  00:23:42<01:22:06  0.08it/s  112/500  0.0713
# Description  22.4% |██████████████████████                                                                             |  Iters     Elapsed Time      Speed     epoch    loss
#  113/500  00:23:54<01:21:51  0.08it/s  113/500  0.0709
# Description  22.6% |██████████████████████                                                                             |  Iters     Elapsed Time      Speed     epoch    loss
#  114/500  00:24:06<01:21:36  0.08it/s  114/500  0.0710
# Description  22.8% |██████████████████████                                                                             |  Iters     Elapsed Time      Speed     epoch    loss
#  115/500  00:24:17<01:21:20  0.08it/s  115/500  0.0711
# Description  23.0% |██████████████████████                                                                             |  Iters     Elapsed Time      Speed     epoch    loss
#  116/500  00:24:29<01:21:05  0.08it/s  116/500  0.0710
# Description  23.2% |██████████████████████                                                                             |  Iters     Elapsed Time      Speed     epoch    loss
#  117/500  00:24:41<01:20:51  0.08it/s  117/500  0.0708
# Description  23.4% |███████████████████████                                                                            |  Iters     Elapsed Time      Speed     epoch    loss
#  118/500  00:24:54<01:20:37  0.08it/s  118/500  0.0708
# Description  23.6% |███████████████████████                                                                            |  Iters     Elapsed Time      Speed     epoch    loss
#  119/500  00:25:06<01:20:22  0.08it/s  119/500  0.0712
# Description  23.8% |███████████████████████                                                                            |  Iters     Elapsed Time      Speed     epoch    loss
#  120/500  00:25:18<01:20:08  0.08it/s  120/500  0.0707
# Description  24.0% |███████████████████████                                                                            |  Iters     Elapsed Time      Speed     epoch    loss
#  121/500  00:25:30<01:19:54  0.08it/s  121/500  0.0708
# Description  24.2% |███████████████████████                                                                            |  Iters     Elapsed Time      Speed     epoch    loss
#  122/500  00:25:43<01:19:40  0.08it/s  122/500  0.0706
# Description  24.4% |████████████████████████                                                                           |  Iters     Elapsed Time      Speed     epoch    loss
#  123/500  00:25:54<01:19:25  0.08it/s  123/500  0.0708
# Description  24.6% |████████████████████████                                                                           |  Iters     Elapsed Time      Speed     epoch    loss
#  124/500  00:26:06<01:19:11  0.08it/s  124/500  0.0706
# Description  24.8% |████████████████████████                                                                           |  Iters     Elapsed Time      Speed     epoch    loss
#  125/500  00:26:18<01:18:55  0.08it/s  125/500  0.0708
# Description  25.0% |████████████████████████                                                                           |  Iters     Elapsed Time      Speed     epoch    loss
#  126/500  00:26:30<01:18:40  0.08it/s  126/500  0.0706
# Description  25.2% |████████████████████████                                                                           |  Iters     Elapsed Time      Speed     epoch    loss
#  127/500  00:26:42<01:18:25  0.08it/s  127/500  0.0704
# Description  25.4% |█████████████████████████                                                                          |  Iters     Elapsed Time      Speed     epoch    loss
#  128/500  00:26:53<01:18:09  0.08it/s  128/500  0.0704
# Description  25.6% |█████████████████████████                                                                          |  Iters     Elapsed Time      Speed     epoch    loss
#  129/500  00:27:05<01:17:54  0.08it/s  129/500  0.0707
# Description  25.8% |█████████████████████████                                                                          |  Iters     Elapsed Time      Speed     epoch    loss
#  130/500  00:27:17<01:17:39  0.08it/s  130/500  0.0704
# Description  26.0% |█████████████████████████                                                                          |  Iters     Elapsed Time      Speed     epoch    loss
#  131/500  00:27:28<01:17:24  0.08it/s  131/500  0.0703
# Description  26.2% |█████████████████████████                                                                          |  Iters     Elapsed Time      Speed     epoch    loss
# ...
#  458/500  01:31:10<00:08:21  0.08it/s  458/500  0.0654
# Description  91.6% |██████████████████████████████████████████████████████████████████████████████████████████         |  Iters     Elapsed Time      Speed     epoch    loss
#  459/500  01:31:22<00:08:09  0.08it/s  459/500  0.0652
# Description  91.8% |██████████████████████████████████████████████████████████████████████████████████████████         |  Iters     Elapsed Time      Speed     epoch    loss
#  460/500  01:31:34<00:07:57  0.08it/s  460/500  0.0654
# Description  92.0% |███████████████████████████████████████████████████████████████████████████████████████████        |  Iters     Elapsed Time      Speed     epoch    loss
#  461/500  01:31:45<00:07:45  0.08it/s  461/500  0.0657
# Description  92.2% |███████████████████████████████████████████████████████████████████████████████████████████        |  Iters     Elapsed Time      Speed     epoch    loss
#  462/500  01:31:57<00:07:33  0.08it/s  462/500  0.0653
# Description  92.4% |███████████████████████████████████████████████████████████████████████████████████████████        |  Iters     Elapsed Time      Speed     epoch    loss
#  463/500  01:32:08<00:07:21  0.08it/s  463/500  0.0654
# Description  92.6% |███████████████████████████████████████████████████████████████████████████████████████████        |  Iters     Elapsed Time      Speed     epoch    loss
#  464/500  01:32:20<00:07:09  0.08it/s  464/500  0.0654
# Description  92.8% |███████████████████████████████████████████████████████████████████████████████████████████        |  Iters     Elapsed Time      Speed     epoch    loss
#  465/500  01:32:32<00:06:57  0.08it/s  465/500  0.0654
# Description  93.0% |████████████████████████████████████████████████████████████████████████████████████████████       |  Iters     Elapsed Time      Speed     epoch    loss
#  466/500  01:32:43<00:06:45  0.08it/s  466/500  0.0653
# Description  93.2% |████████████████████████████████████████████████████████████████████████████████████████████       |  Iters     Elapsed Time      Speed     epoch    loss
#  467/500  01:32:55<00:06:33  0.08it/s  467/500  0.0654
# Description  93.4% |████████████████████████████████████████████████████████████████████████████████████████████       |  Iters     Elapsed Time      Speed     epoch    loss
#  468/500  01:33:07<00:06:22  0.08it/s  468/500  0.0652
# Description  93.6% |████████████████████████████████████████████████████████████████████████████████████████████       |  Iters     Elapsed Time      Speed     epoch    loss
#  469/500  01:33:19<00:06:10  0.08it/s  469/500  0.0654
# Description  93.8% |████████████████████████████████████████████████████████████████████████████████████████████       |  Iters     Elapsed Time      Speed     epoch    loss
#  470/500  01:33:30<00:05:58  0.08it/s  470/500  0.0653
# Description  94.0% |█████████████████████████████████████████████████████████████████████████████████████████████      |  Iters     Elapsed Time      Speed     epoch    loss
#  471/500  01:33:42<00:05:46  0.08it/s  471/500  0.0654
# Description  94.2% |█████████████████████████████████████████████████████████████████████████████████████████████      |  Iters     Elapsed Time      Speed     epoch    loss
#  472/500  01:33:54<00:05:34  0.08it/s  472/500  0.0653
# Description  94.4% |█████████████████████████████████████████████████████████████████████████████████████████████      |  Iters     Elapsed Time      Speed     epoch    loss
#  473/500  01:34:05<00:05:22  0.08it/s  473/500  0.0653
# Description  94.6% |█████████████████████████████████████████████████████████████████████████████████████████████      |  Iters     Elapsed Time      Speed     epoch    loss
#  474/500  01:34:17<00:05:10  0.08it/s  474/500  0.0653
# Description  94.8% |█████████████████████████████████████████████████████████████████████████████████████████████      |  Iters     Elapsed Time      Speed     epoch    loss
#  475/500  01:34:29<00:04:58  0.08it/s  475/500  0.0653
# Description  95.0% |██████████████████████████████████████████████████████████████████████████████████████████████     |  Iters     Elapsed Time      Speed     epoch    loss
#  476/500  01:34:41<00:04:46  0.08it/s  476/500  0.0651
# Description  95.2% |██████████████████████████████████████████████████████████████████████████████████████████████     |  Iters     Elapsed Time      Speed     epoch    loss
#  477/500  01:34:52<00:04:34  0.08it/s  477/500  0.0654
# Description  95.4% |██████████████████████████████████████████████████████████████████████████████████████████████     |  Iters     Elapsed Time      Speed     epoch    loss
#  478/500  01:35:04<00:04:22  0.08it/s  478/500  0.0655
# Description  95.6% |██████████████████████████████████████████████████████████████████████████████████████████████     |  Iters     Elapsed Time      Speed     epoch    loss
#  479/500  01:35:15<00:04:10  0.08it/s  479/500  0.0652
# Description  95.8% |██████████████████████████████████████████████████████████████████████████████████████████████     |  Iters     Elapsed Time      Speed     epoch    loss
#  480/500  01:35:27<00:03:58  0.08it/s  480/500  0.0651
# Description  96.0% |███████████████████████████████████████████████████████████████████████████████████████████████    |  Iters     Elapsed Time      Speed     epoch    loss
#  481/500  01:35:39<00:03:46  0.08it/s  481/500  0.0651
# Description  96.2% |███████████████████████████████████████████████████████████████████████████████████████████████    |  Iters     Elapsed Time      Speed     epoch    loss
#  482/500  01:35:50<00:03:34  0.08it/s  482/500  0.0656
# Description  96.4% |███████████████████████████████████████████████████████████████████████████████████████████████    |  Iters     Elapsed Time      Speed     epoch    loss
#  483/500  01:36:02<00:03:22  0.08it/s  483/500  0.0656
# Description  96.6% |███████████████████████████████████████████████████████████████████████████████████████████████    |  Iters     Elapsed Time      Speed     epoch    loss
#  484/500  01:36:13<00:03:10  0.08it/s  484/500  0.0651
# Description  96.8% |███████████████████████████████████████████████████████████████████████████████████████████████    |  Iters     Elapsed Time      Speed     epoch    loss
#  485/500  01:36:25<00:02:58  0.08it/s  485/500  0.0651
# Description  97.0% |████████████████████████████████████████████████████████████████████████████████████████████████   |  Iters     Elapsed Time      Speed     epoch    loss
#  486/500  01:36:36<00:02:46  0.08it/s  486/500  0.0651
# Description  97.2% |████████████████████████████████████████████████████████████████████████████████████████████████   |  Iters     Elapsed Time      Speed     epoch    loss
#  487/500  01:36:48<00:02:35  0.08it/s  487/500  0.0651
# Description  97.4% |████████████████████████████████████████████████████████████████████████████████████████████████   |  Iters     Elapsed Time      Speed     epoch    loss
#  488/500  01:37:00<00:02:23  0.08it/s  488/500  0.0650
# Description  97.6% |████████████████████████████████████████████████████████████████████████████████████████████████   |  Iters     Elapsed Time      Speed     epoch    loss
#  489/500  01:37:11<00:02:11  0.08it/s  489/500  0.0653
# Description  97.8% |████████████████████████████████████████████████████████████████████████████████████████████████   |  Iters     Elapsed Time      Speed     epoch    loss
#  490/500  01:37:23<00:01:59  0.08it/s  490/500  0.0653
# Description  98.0% |█████████████████████████████████████████████████████████████████████████████████████████████████  |  Iters     Elapsed Time      Speed     epoch    loss
#  491/500  01:37:34<00:01:47  0.08it/s  491/500  0.0651
# Description  98.2% |█████████████████████████████████████████████████████████████████████████████████████████████████  |  Iters     Elapsed Time      Speed     epoch    loss
#  492/500  01:37:46<00:01:35  0.08it/s  492/500  0.0650
# Description  98.4% |█████████████████████████████████████████████████████████████████████████████████████████████████  |  Iters     Elapsed Time      Speed     epoch    loss
#  493/500  01:37:57<00:01:23  0.08it/s  493/500  0.0656
# Description  98.6% |█████████████████████████████████████████████████████████████████████████████████████████████████  |  Iters     Elapsed Time      Speed     epoch    loss
#  494/500  01:38:09<00:01:11  0.08it/s  494/500  0.0651
# Description  98.8% |█████████████████████████████████████████████████████████████████████████████████████████████████  |  Iters     Elapsed Time      Speed     epoch    loss
#  495/500  01:38:20<00:00:59  0.08it/s  495/500  0.0654
# Description  99.0% |██████████████████████████████████████████████████████████████████████████████████████████████████ |  Iters     Elapsed Time      Speed     epoch    loss
#  496/500  01:38:32<00:00:47  0.08it/s  496/500  0.0652
# Description  99.2% |██████████████████████████████████████████████████████████████████████████████████████████████████ |  Iters     Elapsed Time      Speed     epoch    loss
#  497/500  01:38:43<00:00:35  0.08it/s  497/500  0.0651
# Description  99.4% |██████████████████████████████████████████████████████████████████████████████████████████████████ |  Iters     Elapsed Time      Speed     epoch    loss
#  498/500  01:38:55<00:00:23  0.08it/s  498/500  0.0650
# Description  99.6% |██████████████████████████████████████████████████████████████████████████████████████████████████ |  Iters     Elapsed Time      Speed     epoch    loss
#  499/500  01:39:07<00:00:11  0.08it/s  499/500  0.0649
# Description  99.8% |██████████████████████████████████████████████████████████████████████████████████████████████████ |  Iters     Elapsed Time      Speed     epoch    loss
#  500/500  01:39:19<00:00:00  0.08it/s  500/500  0.0653
# Description 100.0% |███████████████████████████████████████████████████████████████████████████████████████████████████|  Iters     Elapsed Time      Speed     epoch    loss
#  500/500  01:39:19<00:00:00  0.08it/s  500/500  0.0653
# Description 100.0% |███████████████████████████████████████████████████████████████████████████████████████████████████|

# %% [markdown]
# # Inference
# Model is loaded and generates its anomaly score predictions.

# %% [markdown]
# ## Initialize
# - dataloader
# - model
# - prediction file

# %%
eval_batch_size = 200

# build testing dataloader
data = torch.tensor(test, dtype=torch.float32)
test_dataset = CustomTensorDataset(data)
test_sampler = SequentialSampler(test_dataset)
test_dataloader = DataLoader(test_dataset, sampler=test_sampler, batch_size=eval_batch_size, num_workers=1)
eval_loss = nn.MSELoss(reduction='none')

# load trained model
# checkpoint_path = f'last_model_{model_type}.pt'
checkpoint_path = f'best_model_{model_type}.pt'
model = torch.load(checkpoint_path)
model.eval()

# prediction file 
out_file = 'prediction.csv'

# %%
anomality = list()
with torch.no_grad():
  for i, data in enumerate(test_dataloader):
    img = data.float().cuda()
    if model_type in ['fcn', 'multi_fcn']:
      img = img.view(img.shape[0], -1)
    output = model(img)
    if model_type in ['vae']:
      output = output[0]
    if model_type in ['fcn', 'multi_fcn']:
        loss = eval_loss(output, img).sum(-1)
    else:
        loss = eval_loss(output, img).sum([1, 2, 3])
    anomality.append(loss)
anomality = torch.cat(anomality, axis=0)
anomality = torch.sqrt(anomality).reshape(len(test), 1).cpu().numpy()

df = pd.DataFrame(anomality, columns=['score'])
df.to_csv(out_file, index_label = 'ID')

# %%
# ref: https://colab.research.google.com/github/smartgeometry-ucl/dl4g/blob/master/variational_autoencoder.ipynb

import torchvision
import matplotlib.pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def to_img(x):
    x = x.clamp(0, 1)
    return x

def show_image(img):
    img = to_img(img)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

def visualise_output(images, model):

    with torch.no_grad():
    
        images = images.to(device)
        
        if model_type in ['fcn']:
            images = images.view(images.shape[0], -1)
            
        images = model(images)
        
        if model_type in ['vae']:
            images = images[0]
        
        images = images.cpu()
        images = to_img(images)
        images = images.reshape(200, 3, 64, 64)
        np_imagegrid = torchvision.utils.make_grid(images[1:50], 10, 5).numpy()
        plt.imshow(np.transpose(np_imagegrid, (1, 2, 0)))
        plt.show()
                
images = iter(test_dataloader).next()

print('original images:')
show_image(torchvision.utils.make_grid(images[1:50], 10, 5))
plt.show()
    
print('model reconstruction:')
visualise_output(images, model)

# %%
images = iter(test_dataloader).next()

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
images = images.to(device)
if model_type in ['fcn']:
    images = images.view(images.shape[0], -1)
images = model(images)
if model_type in ['vae']:
    images = images[0]
    
images = images.cpu()
images = images.reshape(200, 3, 64, 64)

img = images[8]
plt.imshow(img.permute(1, 2, 0).detach().numpy())
plt.show()

# %%
# 過每個base line要5小時，epoch 200、300
# fcnn 比較好過
# dimension調高，epoch 2000、batch_size=128會變爛



# ======================================================== #



# strong

# 助教是用三個fcnn
# 建立三個不同的encoder架構（只有encoder不一樣，decoder只有一個）
# 把三個出來的representation直接接在一起
# 會變成比較長的vector
# 在直接丟到decoder
# e.g., 每個印出來是三維，疊起來是九維，那decoder第一層就要改成9維



# ======================================================== #



# report

# fully connected
# 丟到encoder是三維向量 e.g., 2, 4, 6
# 丟到decoder可能是原本img
# 希望對某一維度*2 e.g., 變成4, 4, 6，再去重建 e.g., z[1]=z[1]*2
# 看看有沒有什麼不一樣的地方

# 要動encoder output
# 比較的是decoder output

# 在forward
# x = self.encoder(x)
# x[:, i] = x[:, i] * 2 or x[:, i] = 0 -> 因為第一維是放很多張照片
# x = delf.decoder(x)
